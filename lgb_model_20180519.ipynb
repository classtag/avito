# %%
# coding: utf-8
"""
train lightgbm model
"""
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import lightgbm as lgb

import gc
import pickle
from datetime import datetime
from scipy import sparse
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import mean_squared_error

file_stamp = datetime.now().strftime('%m%d%H%M')

root = '/kaggle/competitions/avito-demand-prediction/'

def load_matrix(name):
    return pickle.load(open(root + 'features/{}.pkl'.format(name), 'rb'))

# %%
tr_index = load_matrix('tr_index')
te_index = load_matrix('te_index')

X = load_matrix('X_20180519')
y = load_matrix('y')
X_te = load_matrix('X_20180519_te')
feature_names = load_matrix('lgb_feature_20180519')

# %%
def cut_feature(feature_importance_):
    global feature_names
    feature_weak_ = [x[0] for x in feature_importance_ if x[1]==0.0]
    feature_index = [i for i, c in enumerate(feature_names) if c not in feature_weak_]
    _feature_names = [c for i, c in enumerate(feature_names) if c not in feature_weak_]
    _X    = sparse.lil_matrix(X[:,feature_index])
    _X_te = sparse.lil_matrix(X_te[:,feature_index])
    print('cut feature {}%'.format(100*len(feature_weak_)/len(feature_importance_)))
    return _X, _X_te, _feature_names

# %%
def rmse(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))

# %%
num_boost_round = 20000
params = {
    'objective': 'regression',
    'metric': 'rmse',
    'learning_rate': 0.1,
    'num_leaves': 15,
    'max_bin': 256,
    'feature_fraction': 0.6,
    'min_child_samples': 10,
    'min_child_weight': 150,
    'min_split_gain': 0,
    'subsample': 0.9,
    'drop_rate': 0.1,
    'max_drop': 50,
    'verbosity': 0,
    'seed': 228,
}
n_folds = 5
kfold = StratifiedKFold(n_splits=n_folds, shuffle=False, random_state=218)

# %%
# feature selection

# %%
val_split_idx = round(X.shape[0]*.9)
X_tr, X_va, y_tr, y_va = X[:val_split_idx], X[val_split_idx:], y[:val_split_idx], y[val_split_idx:]
print(X_tr.shape, X_va.shape, y_tr.shape[0], y_va.shape[0])
dtrain = lgb.Dataset(X_tr, y_tr, feature_name=feature_names)
dvalid = lgb.Dataset(X_va, y_va, feature_name=feature_names, reference=dtrain)

params['learning_rate'] = 0.2
params['feature_fraction'] = 0.66
gbm = lgb.train(params, dtrain, num_boost_round,
                valid_sets=(dtrain, dvalid),
                valid_names=['train', 'valid'],
                verbose_eval=100,
                early_stopping_rounds=50)
# Out:
# (1353082, 60084) (150342, 60084) 1353082 150342
# (1353082, 60084) (150342, 60084) 1353082 150342
# Training until validation scores don't improve for 50 rounds.
# Training until validation scores don't improve for 50 rounds.
# [100]	train's rmse: 0.224345	valid's rmse: 0.222749
# [100]	train's rmse: 0.224345	valid's rmse: 0.222749
# [200]	train's rmse: 0.222316	valid's rmse: 0.221139
# [200]	train's rmse: 0.222316	valid's rmse: 0.221139
# [300]	train's rmse: 0.221014	valid's rmse: 0.220264
# [300]	train's rmse: 0.221014	valid's rmse: 0.220264
# [400]	train's rmse: 0.220002	valid's rmse: 0.219635
# [400]	train's rmse: 0.220002	valid's rmse: 0.219635
# [500]	train's rmse: 0.219259	valid's rmse: 0.219371
# [500]	train's rmse: 0.219259	valid's rmse: 0.219371
# [600]	train's rmse: 0.218509	valid's rmse: 0.219026
# [600]	train's rmse: 0.218509	valid's rmse: 0.219026
# [700]	train's rmse: 0.217875	valid's rmse: 0.21876
# [700]	train's rmse: 0.217875	valid's rmse: 0.21876
# [800]	train's rmse: 0.217308	valid's rmse: 0.218611
# [800]	train's rmse: 0.217308	valid's rmse: 0.218611
# [900]	train's rmse: 0.216779	valid's rmse: 0.218457
# [900]	train's rmse: 0.216779	valid's rmse: 0.218457
# [1000]	train's rmse: 0.216306	valid's rmse: 0.218337
# [1000]	train's rmse: 0.216306	valid's rmse: 0.218337
# [1100]	train's rmse: 0.215799	valid's rmse: 0.218215
# [1100]	train's rmse: 0.215799	valid's rmse: 0.218215
# [1200]	train's rmse: 0.215321	valid's rmse: 0.218083
# [1200]	train's rmse: 0.215321	valid's rmse: 0.218083
# [1300]	train's rmse: 0.214902	valid's rmse: 0.217988
# [1300]	train's rmse: 0.214902	valid's rmse: 0.217988
# [1400]	train's rmse: 0.214431	valid's rmse: 0.217878
# [1400]	train's rmse: 0.214431	valid's rmse: 0.217878
# Early stopping, best iteration is:
# [1417]	train's rmse: 0.214357	valid's rmse: 0.217865
# Early stopping, best iteration is:
# [1417]	train's rmse: 0.214357	valid's rmse: 0.217865
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-fbe68919aa9e> in <module>()
#      12                 verbose_eval=100,
#      13                 early_stopping_rounds=50)
# ---> 14 y_hat += gbm.predict(X_va)
#      15 score = rmse(y_va, y_hat)
#      16 print('rmse:', score)
#
# NameError: name 'y_hat' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-fbe68919aa9e> in <module>()
#      12                 verbose_eval=100,
#      13                 early_stopping_rounds=50)
# ---> 14 y_hat += gbm.predict(X_va)
#      15 score = rmse(y_va, y_hat)
#      16 print('rmse:', score)
#
# NameError: name 'y_hat' is not defined

# %%
y_hat = gbm.predict(X_va)
score = rmse(y_va, y_hat)
print('rmse:', score)
feature_importance_ = zip(feature_names, gbm.feature_importance())
feature_importance_ = sorted(feature_importance_, key=lambda x: x[1], reverse=True)
print('\n'.join(('%s: %.2f' % x) for x in feature_importance_[:100]))
# Out:
# rmse: 0.21786545260568901
# price: 1034.00
# image_top_1_cluster: 406.00
# avg_days_up_user: 394.00
# n_user_items: 356.00
# n_image_top_1_price_avg: 280.00
# avg_times_up_user: 255.00
# item_seq_number: 245.00
# param_1_cluster: 218.00
# city_cluster: 217.00
# c2v_3: 199.00
# c2v_1: 194.00
# r_desc_pun: 193.00
# c2v_5: 185.00
# r_titl_des: 182.00
# image_top_1: 180.00
# c2v_8: 178.00
# c2v_9: 174.00
# r_desc_dig: 169.00
# c2v_0: 165.00
# c2v_4: 164.00
# c2v_2: 160.00
# r_desc_cap: 157.00
# n_desc_len: 155.00
# r_desc_spa: 153.00
# c2v_7: 152.00
# r_desc_wds: 146.00
# r_titl_spa: 140.00
# n_titl_len: 134.00
# c2v_6: 134.00
# n_char_params: 132.00
# r_titl_wds: 124.00
# r_titl_cap: 117.00
# city_uv: 115.00
# item_seq_number_uv: 112.00
# n_desc_dig: 105.00
# n_text_wds: 99.00
# n_region_price_avg: 98.00
# city_upv: 98.00
# region_upv: 97.00
# n_desc_pun: 93.00
# n_category_name_price_avg: 90.00
# n_desc_spa: 87.00
# r_titl_dig: 85.00
# category_name_upv: 83.00
# region_factor: 82.00
# category_name_uv: 76.00
# n_desc_cap: 76.00
# image_top_1_uv: 73.00
# r_titl_pun: 68.00
# n_desc_wds: 68.00
# n_day_of_week_price_avg: 64.00
# r_desc_row: 60.00
# t2v_состоянии: 55.00
# day_of_week_factor: 53.00
# category_name_cluster: 46.00
# image_top_1_upv: 44.00
# region_uv: 43.00
# n_parent_category_name_price_avg: 42.00
# parent_category_name_upv: 39.00
# n_titl_cap: 38.00
# day_of_week_upv: 37.00
# n_titl_wds: 32.00
# user_type_factor: 31.00
# n_desc_row: 30.00
# t2v_отдам: 30.00
# n_missing_features: 28.00
# parent_category_name_factor: 28.00
# t2v_продам: 27.00
# parent_category_name_uv: 26.00
# p2v_исключение: 24.00
# n_titl_dig: 20.00
# t2v_ремонт: 18.00
# n_user_type_price_avg: 16.00
# day_of_week_uv: 16.00
# t2v_состояние: 16.00
# t2v_даром: 15.00
# t2v_кровать: 14.00
# t2v_резиновые: 14.00
# n_titl_pun: 13.00
# t2v_crocs: 13.00
# t2v_велосипед: 13.00
# t2v_велосипеды: 13.00
# t2v_грузоперевозки: 13.00
# t2v_мебель: 13.00
# t2v_коляска: 12.00
# t2v_новые: 12.00
# t2v_птицы: 12.00
# t2v_ходунки: 12.00
# r_desc_emo: 11.00
# t2v_ecco: 11.00
# t2v_zara: 11.00
# t2v_наращивание: 11.00
# t2v_продаю: 11.00
# t2v_стол: 11.00
# n_titl_spa: 10.00
# t2v_абонемент: 10.00
# t2v_автолюлька: 10.00
# t2v_ботинки: 10.00
# t2v_мебель интерьер: 10.00
# t2v_санки: 10.00
# rmse: 0.21786545260568901
# price: 1034.00
# image_top_1_cluster: 406.00
# avg_days_up_user: 394.00
# n_user_items: 356.00
# n_image_top_1_price_avg: 280.00
# avg_times_up_user: 255.00
# item_seq_number: 245.00
# param_1_cluster: 218.00
# city_cluster: 217.00
# c2v_3: 199.00
# c2v_1: 194.00
# r_desc_pun: 193.00
# c2v_5: 185.00
# r_titl_des: 182.00
# image_top_1: 180.00
# c2v_8: 178.00
# c2v_9: 174.00
# r_desc_dig: 169.00
# c2v_0: 165.00
# c2v_4: 164.00
# c2v_2: 160.00
# r_desc_cap: 157.00
# n_desc_len: 155.00
# r_desc_spa: 153.00
# c2v_7: 152.00
# r_desc_wds: 146.00
# r_titl_spa: 140.00
# n_titl_len: 134.00
# c2v_6: 134.00
# n_char_params: 132.00
# r_titl_wds: 124.00
# r_titl_cap: 117.00
# city_uv: 115.00
# item_seq_number_uv: 112.00
# n_desc_dig: 105.00
# n_text_wds: 99.00
# n_region_price_avg: 98.00
# city_upv: 98.00
# region_upv: 97.00
# n_desc_pun: 93.00
# n_category_name_price_avg: 90.00
# n_desc_spa: 87.00
# r_titl_dig: 85.00
# category_name_upv: 83.00
# region_factor: 82.00
# category_name_uv: 76.00
# n_desc_cap: 76.00
# image_top_1_uv: 73.00
# r_titl_pun: 68.00
# n_desc_wds: 68.00
# n_day_of_week_price_avg: 64.00
# r_desc_row: 60.00
# t2v_состоянии: 55.00
# day_of_week_factor: 53.00
# category_name_cluster: 46.00
# image_top_1_upv: 44.00
# region_uv: 43.00
# n_parent_category_name_price_avg: 42.00
# parent_category_name_upv: 39.00
# n_titl_cap: 38.00
# day_of_week_upv: 37.00
# n_titl_wds: 32.00
# user_type_factor: 31.00
# n_desc_row: 30.00
# t2v_отдам: 30.00
# n_missing_features: 28.00
# parent_category_name_factor: 28.00
# t2v_продам: 27.00
# parent_category_name_uv: 26.00
# p2v_исключение: 24.00
# n_titl_dig: 20.00
# t2v_ремонт: 18.00
# n_user_type_price_avg: 16.00
# day_of_week_uv: 16.00
# t2v_состояние: 16.00
# t2v_даром: 15.00
# t2v_кровать: 14.00
# t2v_резиновые: 14.00
# n_titl_pun: 13.00
# t2v_crocs: 13.00
# t2v_велосипед: 13.00
# t2v_велосипеды: 13.00
# t2v_грузоперевозки: 13.00
# t2v_мебель: 13.00
# t2v_коляска: 12.00
# t2v_новые: 12.00
# t2v_птицы: 12.00
# t2v_ходунки: 12.00
# r_desc_emo: 11.00
# t2v_ecco: 11.00
# t2v_zara: 11.00
# t2v_наращивание: 11.00
# t2v_продаю: 11.00
# t2v_стол: 11.00
# n_titl_spa: 10.00
# t2v_абонемент: 10.00
# t2v_автолюлька: 10.00
# t2v_ботинки: 10.00
# t2v_мебель интерьер: 10.00
# t2v_санки: 10.00

# %%
cv_pr = gbm.predict(X_te, num_iteration=gbm.best_iteration)
pr_hat = pd.Series(np.clip(cv_pr, 0, 1), name='deal_probability', index=te_index)

pr_hat_file = root+'results/lgb_base_pr_{}_{}.csv'.format(file_stamp, score)
pr_hat.to_csv(pr_hat_file, header=True)

# %% [markdown]
# # cut feature then train

# %%
X, X_te, feature_names = cut_feature(feature_importance_)
# Out:
# cut feature 91.29385526928966%
# cut feature 91.29385526928966%

# %%
categorical = list(filter(lambda c: c.endswith('_cluster'),feature_names))

# %%
n_models = 8
x_score = []
final_cv_tr = np.zeros(len(y))
final_cv_pr = np.zeros(len(te_index))

# %%
params['learning_rate'] = 0.067
# params['feature_fraction'] = 0.86

for s in range(n_models):
    cv_tr = np.zeros(len(y))
    cv_pr = np.zeros(len(te_index))
    
    print(20 * '*' + 'lgb[{}]'.format(s) + 21 * '*')
    kf = kfold.split(X, round(y))
    best_trees = []
    fold_scores = []
    
    for i, (tr, va) in enumerate(kf):
        print(20 * '/' + 'lgb[{}]'.format(s), 'cv[{}]'.format(i) + 15 * '/')
        params['seed'] = s * i
        
        X_tr, X_va, y_tr, y_va = X[tr, :], X[va, :], y[tr], y[va]
        print(X_tr.shape, X_va.shape)
        dtrain = lgb.Dataset(X_tr, y_tr, feature_name=feature_names)
        dvalid = lgb.Dataset(X_va, y_va, feature_name=feature_names, reference=dtrain)
        gbm = lgb.train(params, dtrain, num_boost_round,
                        valid_sets=(dtrain, dvalid),
                        valid_names=['train', 'valid'],
                        verbose_eval=100,
                        early_stopping_rounds=50)
        best_trees.append(gbm.best_iteration)
        cv_pr += gbm.predict(X_te, num_iteration=gbm.best_iteration)
        cv_tr[va] += gbm.predict(X_va)
        score = rmse(y_va, cv_tr[va])
        print('lgb[{}]'.format(s), 'cv[{}]'.format(i), 'rmse:', score)
        fold_scores.append(score)
        feature_importance_ = zip(feature_names, gbm.feature_importance())
        feature_importance_ = sorted(feature_importance_, key=lambda x: x[1], reverse=True)
        pickle.dump(feature_importance_, open(root + 'results/lgb_20180519_{}_{}_feature_importance.pkl'.format(s, i), 'wb'))
        print('lgb[{}]'.format(s), 'cv[{}]'.format(i), 'importance features')
        print('\n'.join(('%s: %.2f' % x) for x in feature_importance_[:100]))
        print(50 * '/')
        
    cv_pr /= n_folds
    final_cv_tr += cv_tr
    final_cv_pr += cv_pr

    fold_score = rmse(y, cv_tr)
    x_score.append(fold_score)
    print('lgb[{}]'.format(s), 'fold score:', fold_score)
    print('lgb[{}]'.format(s), 'mean score:', rmse(y, cv_tr) / (s + 1.0), s + 1)
    print('lgb[{}]'.format(s), fold_scores)
    print('lgb[{}]'.format(s), best_trees, np.mean(best_trees))
# Out:
# ********************lgb[0]*********************
# ********************lgb[0]*********************
# ////////////////////lgb[0] cv[0]///////////////
# ////////////////////lgb[0] cv[0]///////////////
# (1202739, 5231) (300685, 5231)
# (1202739, 5231) (300685, 5231)
# Training until validation scores don't improve for 50 rounds.
# Training until validation scores don't improve for 50 rounds.
# [100]	train's rmse: 0.227233	valid's rmse: 0.228275
# [100]	train's rmse: 0.227233	valid's rmse: 0.228275
# [200]	train's rmse: 0.225078	valid's rmse: 0.226322
# [200]	train's rmse: 0.225078	valid's rmse: 0.226322
# [300]	train's rmse: 0.223846	valid's rmse: 0.225278
# [300]	train's rmse: 0.223846	valid's rmse: 0.225278
# [400]	train's rmse: 0.22298	valid's rmse: 0.224583
# [400]	train's rmse: 0.22298	valid's rmse: 0.224583
# [500]	train's rmse: 0.22232	valid's rmse: 0.22409
# [500]	train's rmse: 0.22232	valid's rmse: 0.22409
# [600]	train's rmse: 0.221737	valid's rmse: 0.223685
# [600]	train's rmse: 0.221737	valid's rmse: 0.223685
# [700]	train's rmse: 0.221259	valid's rmse: 0.223386
# [700]	train's rmse: 0.221259	valid's rmse: 0.223386
# [800]	train's rmse: 0.22081	valid's rmse: 0.223103
# [800]	train's rmse: 0.22081	valid's rmse: 0.223103
# [900]	train's rmse: 0.220415	valid's rmse: 0.222865
# [900]	train's rmse: 0.220415	valid's rmse: 0.222865
# [1000]	train's rmse: 0.220045	valid's rmse: 0.222665
# [1000]	train's rmse: 0.220045	valid's rmse: 0.222665
# [1100]	train's rmse: 0.2197	valid's rmse: 0.222482
# [1100]	train's rmse: 0.2197	valid's rmse: 0.222482
# [1200]	train's rmse: 0.219378	valid's rmse: 0.222306
# [1200]	train's rmse: 0.219378	valid's rmse: 0.222306
# [1300]	train's rmse: 0.219054	valid's rmse: 0.222154
# [1300]	train's rmse: 0.219054	valid's rmse: 0.222154
# [1400]	train's rmse: 0.218767	valid's rmse: 0.222021
# [1400]	train's rmse: 0.218767	valid's rmse: 0.222021
# [1500]	train's rmse: 0.218478	valid's rmse: 0.221895
# [1500]	train's rmse: 0.218478	valid's rmse: 0.221895
# [1600]	train's rmse: 0.218201	valid's rmse: 0.221781
# [1600]	train's rmse: 0.218201	valid's rmse: 0.221781
# [1700]	train's rmse: 0.217951	valid's rmse: 0.22168
# [1700]	train's rmse: 0.217951	valid's rmse: 0.22168
# [1800]	train's rmse: 0.217709	valid's rmse: 0.221583
# [1800]	train's rmse: 0.217709	valid's rmse: 0.221583
# [1900]	train's rmse: 0.217465	valid's rmse: 0.22149
# [1900]	train's rmse: 0.217465	valid's rmse: 0.22149
# [2000]	train's rmse: 0.217217	valid's rmse: 0.221375
# [2000]	train's rmse: 0.217217	valid's rmse: 0.221375
# [2100]	train's rmse: 0.216991	valid's rmse: 0.22129
# [2100]	train's rmse: 0.216991	valid's rmse: 0.22129
# [2200]	train's rmse: 0.216765	valid's rmse: 0.221213
# [2200]	train's rmse: 0.216765	valid's rmse: 0.221213
# [2300]	train's rmse: 0.21653	valid's rmse: 0.221127
# [2300]	train's rmse: 0.21653	valid's rmse: 0.221127
# [2400]	train's rmse: 0.216328	valid's rmse: 0.221054
# [2400]	train's rmse: 0.216328	valid's rmse: 0.221054
# [2500]	train's rmse: 0.216134	valid's rmse: 0.220997
# [2500]	train's rmse: 0.216134	valid's rmse: 0.220997
# [2600]	train's rmse: 0.215932	valid's rmse: 0.220925
# [2600]	train's rmse: 0.215932	valid's rmse: 0.220925
# [2700]	train's rmse: 0.215741	valid's rmse: 0.220856
# [2700]	train's rmse: 0.215741	valid's rmse: 0.220856
# [2800]	train's rmse: 0.215553	valid's rmse: 0.220794
# [2800]	train's rmse: 0.215553	valid's rmse: 0.220794
# [2900]	train's rmse: 0.215371	valid's rmse: 0.220744
# [2900]	train's rmse: 0.215371	valid's rmse: 0.220744
# [3000]	train's rmse: 0.21519	valid's rmse: 0.22069
# [3000]	train's rmse: 0.21519	valid's rmse: 0.22069
# [3100]	train's rmse: 0.214996	valid's rmse: 0.220637
# [3100]	train's rmse: 0.214996	valid's rmse: 0.220637
# [3200]	train's rmse: 0.214804	valid's rmse: 0.220561
# [3200]	train's rmse: 0.214804	valid's rmse: 0.220561
# [3300]	train's rmse: 0.214637	valid's rmse: 0.220517
# [3300]	train's rmse: 0.214637	valid's rmse: 0.220517
# [3400]	train's rmse: 0.214458	valid's rmse: 0.220461
# [3400]	train's rmse: 0.214458	valid's rmse: 0.220461
# [3500]	train's rmse: 0.21429	valid's rmse: 0.220425
# [3500]	train's rmse: 0.21429	valid's rmse: 0.220425
# [3600]	train's rmse: 0.214128	valid's rmse: 0.220381
# [3600]	train's rmse: 0.214128	valid's rmse: 0.220381
# [3700]	train's rmse: 0.213969	valid's rmse: 0.220345
# [3700]	train's rmse: 0.213969	valid's rmse: 0.220345
# [3800]	train's rmse: 0.213803	valid's rmse: 0.220308
# [3800]	train's rmse: 0.213803	valid's rmse: 0.220308
# [3900]	train's rmse: 0.213633	valid's rmse: 0.220264
# [3900]	train's rmse: 0.213633	valid's rmse: 0.220264
# [4000]	train's rmse: 0.213463	valid's rmse: 0.220215
# [4000]	train's rmse: 0.213463	valid's rmse: 0.220215
# [4100]	train's rmse: 0.213307	valid's rmse: 0.220177
# [4100]	train's rmse: 0.213307	valid's rmse: 0.220177
# [4200]	train's rmse: 0.213145	valid's rmse: 0.220132
# [4200]	train's rmse: 0.213145	valid's rmse: 0.220132
# [4300]	train's rmse: 0.212986	valid's rmse: 0.220097
# [4300]	train's rmse: 0.212986	valid's rmse: 0.220097
# [4400]	train's rmse: 0.21284	valid's rmse: 0.220058
# [4400]	train's rmse: 0.21284	valid's rmse: 0.220058
# [4500]	train's rmse: 0.212699	valid's rmse: 0.220028
# [4500]	train's rmse: 0.212699	valid's rmse: 0.220028
# [4600]	train's rmse: 0.212548	valid's rmse: 0.219992
# [4600]	train's rmse: 0.212548	valid's rmse: 0.219992
# [4700]	train's rmse: 0.212388	valid's rmse: 0.21995
# [4700]	train's rmse: 0.212388	valid's rmse: 0.21995
# [4800]	train's rmse: 0.212239	valid's rmse: 0.219907
# [4800]	train's rmse: 0.212239	valid's rmse: 0.219907
# [4900]	train's rmse: 0.212098	valid's rmse: 0.219874
# [4900]	train's rmse: 0.212098	valid's rmse: 0.219874
# [5000]	train's rmse: 0.211961	valid's rmse: 0.219851
# [5000]	train's rmse: 0.211961	valid's rmse: 0.219851
# [5100]	train's rmse: 0.211817	valid's rmse: 0.219824
# [5100]	train's rmse: 0.211817	valid's rmse: 0.219824
# [5200]	train's rmse: 0.211677	valid's rmse: 0.219789
# [5200]	train's rmse: 0.211677	valid's rmse: 0.219789
# [5300]	train's rmse: 0.211532	valid's rmse: 0.219759
# [5300]	train's rmse: 0.211532	valid's rmse: 0.219759
# [5400]	train's rmse: 0.211402	valid's rmse: 0.219734
# [5400]	train's rmse: 0.211402	valid's rmse: 0.219734
# [5500]	train's rmse: 0.211271	valid's rmse: 0.219711
# [5500]	train's rmse: 0.211271	valid's rmse: 0.219711
# [5600]	train's rmse: 0.211111	valid's rmse: 0.219665
# [5600]	train's rmse: 0.211111	valid's rmse: 0.219665
# [5700]	train's rmse: 0.210969	valid's rmse: 0.219639
# [5700]	train's rmse: 0.210969	valid's rmse: 0.219639
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-1f525cda6afe> in <module>()
#      23                         valid_names=['train', 'valid'],
#      24                         verbose_eval=100,
# ---> 25                         early_stopping_rounds=50)
#      26         best_trees.append(gbm.best_iteration)
#      27         cv_pr += gbm.predict(X_te, num_iteration=gbm.best_iteration)
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/lightgbm/engine.py in train(params, train_set, num_boost_round, valid_sets, valid_names, fobj, feval, init_model, feature_name, categorical_feature, early_stopping_rounds, evals_result, verbose_eval, learning_rates, keep_training_booster, callbacks)
#     199                                     evaluation_result_list=None))
#     200
# --> 201         booster.update(fobj=fobj)
#     202
#     203         evaluation_result_list = []
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/lightgbm/basic.py in update(self, train_set, fobj)
#    1522             _safe_call(_LIB.LGBM_BoosterUpdateOneIter(
#    1523                 self.handle,
# -> 1524                 ctypes.byref(is_finished)))
#    1525             self.__is_predicted_cur_iter = [False for _ in range_(self.__num_dataset)]
#    1526             return is_finished.value == 1
#
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-1f525cda6afe> in <module>()
#      23                         valid_names=['train', 'valid'],
#      24                         verbose_eval=100,
# ---> 25                         early_stopping_rounds=50)
#      26         best_trees.append(gbm.best_iteration)
#      27         cv_pr += gbm.predict(X_te, num_iteration=gbm.best_iteration)
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/lightgbm/engine.py in train(params, train_set, num_boost_round, valid_sets, valid_names, fobj, feval, init_model, feature_name, categorical_feature, early_stopping_rounds, evals_result, verbose_eval, learning_rates, keep_training_booster, callbacks)
#     199                                     evaluation_result_list=None))
#     200
# --> 201         booster.update(fobj=fobj)
#     202
#     203         evaluation_result_list = []
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/lightgbm/basic.py in update(self, train_set, fobj)
#    1522             _safe_call(_LIB.LGBM_BoosterUpdateOneIter(
#    1523                 self.handle,
# -> 1524                 ctypes.byref(is_finished)))
#    1525             self.__is_predicted_cur_iter = [False for _ in range_(self.__num_dataset)]
#    1526             return is_finished.value == 1
#
# KeyboardInterrupt:

# %%
print(50 * '-')
print('Fininsh CV')

print('\n'.join(['lgm[{}] score:{}'.format(*x) for x in enumerate(fold_scores)]))

final_avg_score = round(np.mean(x_score), 6)
final_std_score = round(np.std(x_score), 6)
print('avg score:%.6f' % final_avg_score)
print('std score:%.6f' % final_std_score)

pr_hat = pd.Series(np.clip(final_cv_pr / float(n_models), 0, 1), name='deal_probability', index=te_index)
pr_hat_file = root+'results/lgb_{}_pr_avg_{}_{}.csv'.format(n_models, file_stamp, final_avg_score)
pr_hat.to_csv(pr_hat_file, header=True)

tr_hat = pd.Series(np.clip(final_cv_tr / float(n_models), 0, 1), name='deal_probability', index=tr_index)
tr_hat_file = root+'results/lgb_{}_tr_avg_{}_{}.csv'.format(n_models, file_stamp, final_avg_score)
tr_hat.to_csv(tr_hat_file, header=True)

print('\n'.join([pr_hat_file, tr_hat_file]))
